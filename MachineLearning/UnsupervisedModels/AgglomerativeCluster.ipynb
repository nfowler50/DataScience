# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import AgglomerativeClustering
from sklearn.datasets import make_moons

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import mglearn

X,y=make_blobs(random_state=1)
agg=AgglomerativeClustering(n_clusters=3)
assignment=agg.fit_predict(X)

mglearn.discrete_scatter(X[:,0],X[:,1],assignment)
plt.legend(['cluster 0','cluster 1','cluster 2'],loc='best')
plt.show()

# %%
#linkage criteria:
#ward - default, merges clusters such that variance increases the least
#average - linkage merges clusters with smallest avg dis between points
#complete - linkage merges points such that groups have the smallest maximum distance

# %%
#agg clus only works in 2 dims, for higher dims use dendrograms. SciPy has a good one

from scipy.cluster.hierarchy import dendrogram, ward

X,y=make_blobs(random_state=0,n_samples=12)
linkage_array=ward(X)
dendrogram(linkage_array)

ax=plt.gca()
bounds=ax.get_xbound()

ax.plot(bounds,[7.25,7.25],'--',c='k')
ax.plot(bounds,[4,4],'--',c='k')

plt.show()

# %%
#note the longer lines stepping from 3 clusters to 2 clusters. This indicates that stepping from 3 to 2 involves
#reaching out to more distant points
