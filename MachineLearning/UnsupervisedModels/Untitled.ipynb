# %%
from sklearn.datasets import fetch_lfw_people

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import mglearn

# %%
people=fetch_lfw_people()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-7-059ee4553904> in <module>()
# ----> 1 people=fetch_lfw_people()
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/datasets/lfw.py in fetch_lfw_people(data_home, funneled, resize, min_faces_per_person, color, slice_, download_if_missing)
#     333     faces, target, target_names = load_func(
#     334         data_folder_path, resize=resize,
# --> 335         min_faces_per_person=min_faces_per_person, color=color, slice_=slice_)
#     336
#     337     # pack the results as a Bunch instance
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     560
#     561     def __call__(self, *args, **kwargs):
# --> 562         return self._cached_call(args, kwargs)[0]
#     563
#     564     def __reduce__(self):
#
# ...
