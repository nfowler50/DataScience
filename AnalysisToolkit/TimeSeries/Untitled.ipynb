# %%
import numpy as np
import pandas as pd
from datetime import datetime,timedelta
from dateutil.parser import parse

# %%
now=datetime.now()
now
# Out:
# datetime.datetime(2018, 3, 5, 13, 20, 38, 493533)

# %%
now.year, now.month, now.day
# Out:
# (2018, 3, 5)

# %%
delta=datetime(2011,1,7)-datetime(2008,6,24,8,15)

# %%
delta.days
# Out:
# 926

# %%
delta.seconds
# Out:
# 56700

# %%
start=datetime(2011,1,7)

# %%
start+timedelta(12)
# Out:
# datetime.datetime(2011, 1, 19, 0, 0)

# %%
start-2*timedelta(12)
# Out:
# datetime.datetime(2010, 12, 14, 0, 0)

# %%
stamp=datetime(2011,1,3)
stamp
# Out:
# datetime.datetime(2011, 1, 3, 0, 0)

# %%
str(stamp)
# Out:
# '2011-01-03 00:00:00'

# %%
parse('2011-3-8')
# Out:
# datetime.datetime(2011, 3, 8, 0, 0)

# %%
parse('Jan 3, 1997 10:45 PM')
# Out:
# datetime.datetime(1997, 1, 3, 22, 45)

# %%
parse('6,3,2011', dayfirst=True)
# Out:
# datetime.datetime(2011, 3, 6, 0, 0)

# %%
dates=[datetime(2011,4,6),datetime(1988,3,7),datetime(1994,6,3),datetime(1999,2,7),datetime(2001,9,7),datetime(2006,4,8)]

# %%
ts=pd.Series(np.random.randn(6), index=dates)
ts
# Out:
# 2011-04-06    0.388090
# 1988-03-07    0.440916
# 1994-06-03    0.285218
# 1999-02-07    1.347740
# 2001-09-07    0.294928
# 2006-04-08    0.051124
# dtype: float64

# %%
ts.index
# Out:
# DatetimeIndex(['2011-04-06', '1988-03-07', '1994-06-03', '1999-02-07',
#                '2001-09-07', '2006-04-08'],
#               dtype='datetime64[ns]', freq=None)

# %%
ts+ts[::2] #selects every second item
# Out:
# 1988-03-07         NaN
# 1994-06-03    0.570436
# 1999-02-07         NaN
# 2001-09-07    0.589855
# 2006-04-08         NaN
# 2011-04-06    0.776180
# dtype: float64

# %%
stamp=ts.index[0]
stamp
# Out:
# Timestamp('2011-04-06 00:00:00')

# %%
ts[stamp]
# Out:
# 0.3880902337937685

# %%
longer_ts=pd.Series(np.random.randn(1000),index=pd.date_range('1/1/2000',periods=1000))
longer_ts
# Out:
# 2000-01-01    0.996150
# 2000-01-02   -0.808286
# 2000-01-03   -0.697897
# 2000-01-04   -0.628176
# 2000-01-05    0.236125
# 2000-01-06   -1.561017
# 2000-01-07   -0.545958
# 2000-01-08   -1.107007
# 2000-01-09   -0.527573
# 2000-01-10    0.145077
# 2000-01-11    0.957524
# 2000-01-12    1.554811
# 2000-01-13    0.213598
# 2000-01-14    1.195429
# 2000-01-15   -0.463440
# 2000-01-16   -1.693298
# 2000-01-17   -0.016098
# 2000-01-18   -0.696999
# 2000-01-19   -0.699038
# 2000-01-20    2.012179
# 2000-01-21   -0.749459
# 2000-01-22   -1.854230
# 2000-01-23    0.157912
# 2000-01-24   -2.411992
# 2000-01-25   -0.705122
# 2000-01-26    1.240165
# 2000-01-27   -1.477911
