# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
point=np.arange(-5,5,0.01)
point.shape
# Out:
# (1000,)

# %%
xs,ys=np.meshgrid(point,point)

# %%
zs=np.sqrt(xs**2+ys**2)

# %%
plt.imshow(zs,cmap=plt.cm.gray)
plt.show()

# %%
xarr=np.array([1.1,1.2,1.3,1.4,1.5])
yarr=np.array([2.1,2.2,2.3,2.4,2.5])
cond=np.array([True,False,False,True,False])

result=[(x if c else y) for x,y,c in zip(xarr,yarr,cond)]
result
# Out:
# [1.1000000000000001,
#  2.2000000000000002,
#  2.2999999999999998,
#  1.3999999999999999,
#  2.5]

# %%
result=np.where(cond,xarr,yarr)
result
# Out:
# array([ 1.1,  2.2,  2.3,  1.4,  2.5])

# %%
arr=np.random.randn(4,4)
arr
# Out:
# array([[-0.38937827, -1.41673776,  0.74987888, -0.78597817],
#        [-0.68019768,  0.97413134, -0.53676676,  0.38013768],
#        [-0.2974899 , -2.21304639,  0.26205472,  1.42413557],
#        [ 0.31501524,  0.29321103, -0.93150186,  0.88956667]])

# %%
result=np.where(arr>0,'p','n')
result
# Out:
# array([['n', 'n', 'p', 'n'],
#        ['n', 'p', 'n', 'p'],
#        ['n', 'n', 'p', 'p'],
#        ['p', 'p', 'n', 'p']],
#       dtype='<U1')

# %%
result=np.where(arr>0,arr,'n')
result
# Out:
# array([['n', 'n', '0.7498788768857928', 'n'],
#        ['n', '0.9741313407739798', 'n', '0.3801376766433485'],
#        ['n', 'n', '0.2620547154224887', '1.4241355687941633'],
#        ['0.3150152408783402', '0.2932110310145526', 'n',
#         '0.8895666674800116']],
#       dtype='<U32')

# %%
arr=np.random.randn(5,4)
arr.mean()
# Out:
# 0.13143384398693964

# %%
np.mean(arr)
# Out:
# 0.13143384398693964

# %%
arr.sum()
# Out:
# 2.6286768797387929

# %%
arr.sum(axis=0) #sum over each column
# Out:
# array([ 2.28764991,  0.27590849, -0.18180071,  0.24691919])

# %%
arr.mean(axis=1) #mean over each row
# Out:
# array([-0.3159332 , -0.25501817,  0.44140056,  0.69744609,  0.08927395])

# %%
arr
# Out:
# array([[ 0.45992629, -1.09433594, -0.81475496,  0.1854318 ],
#        [ 0.92393905, -0.26260519, -0.58278417, -1.09862237],
#        [ 0.1756937 ,  0.88344855,  1.09050021, -0.38404022],
#        [-0.32124657,  1.40046109,  0.31772174,  1.39284808],
#        [ 1.04933745, -0.65106002, -0.19248353,  0.15130189]])

# %%
arr=np.arange(8)
arr
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7])

# %%
np.cumsum(arr)
# Out:
# array([ 0,  1,  3,  6, 10, 15, 21, 28])

# %%
arr=np.random.randn(100)
(arr>0).sum()
# Out:
# 59

# %%
bools = arr>0
bools
# Out:
# array([ True, False, False, False, False,  True,  True, False,  True,
#         True,  True,  True,  True,  True,  True, False, False,  True,
#        False,  True,  True, False, False,  True,  True, False, False,
#         True,  True,  True, False,  True, False,  True,  True,  True,
#        False, False, False,  True,  True, False,  True,  True,  True,
#        False, False, False,  True,  True,  True,  True, False,  True,
#        False,  True,  True,  True, False, False,  True, False,  True,
#        False, False,  True, False,  True,  True,  True, False,  True,
#         True, False,  True, False,  True,  True,  True,  True,  True,
#         True,  True, False, False,  True,  True,  True, False, False,
#         True,  True, False, False, False, False,  True,  True, False,  True], dtype=bool)

# %%
bools.any()
# Out:
# True

# %%
bools.all()
# Out:
# False

# %%
arr.sort()
arr
# Out:
# array([-1.82895331, -1.57578144, -1.54380732, -1.51373689, -1.34583721,
#        -1.29985291, -1.20586855, -1.17349017, -1.16357136, -1.10483915,
#        -1.09589681, -1.06896787, -1.0688754 , -1.06788909, -1.03433578,
#        -1.03117517, -0.97633523, -0.93906926, -0.87818036, -0.85860711,
#        -0.84813681, -0.84422213, -0.8390306 , -0.82086296, -0.80580561,
#        -0.80043835, -0.74508676, -0.70940341, -0.70183057, -0.67215926,
#        -0.52779541, -0.5240589 , -0.50187395, -0.47643616, -0.44419085,
#        -0.31320349, -0.3068584 , -0.1807348 , -0.15226604, -0.13277249,
#        -0.01534769,  0.01131165,  0.01167853,  0.02697174,  0.04414403,
#         0.04855116,  0.05722918,  0.0596345 ,  0.08055557,  0.08452571,
#         0.08626889,  0.09274758,  0.11064896,  0.14451551,  0.18557878,
#         0.19357436,  0.19822644,  0.20001127,  0.20453509,  0.21820229,
#         0.31597116,  0.33075019,  0.33156565,  0.33192989,  0.34715698,
# ...

# %%
arr=np.random.randn(5,3)
arr
# Out:
# array([[-0.51914153,  0.03599408, -0.73236587],
#        [-0.17614472, -1.98041445, -2.56943756],
#        [-0.25260123,  1.0914052 ,  0.10111708],
#        [ 0.28693361,  1.75593687,  0.31558758],
#        [ 0.34043875, -1.60779406, -0.15450344]])

# %%
arr.sort(1)
arr
# Out:
# array([[-0.73236587, -0.51914153,  0.03599408],
#        [-2.56943756, -1.98041445, -0.17614472],
#        [-0.25260123,  0.10111708,  1.0914052 ],
#        [ 0.28693361,  0.31558758,  1.75593687],
#        [-1.60779406, -0.15450344,  0.34043875]])

# %%
arr.sort(0)
arr
# Out:
# array([[-0.35708598, -1.5694381 , -1.69473699],
#        [ 0.24830961, -1.49182093, -0.90542928],
#        [ 0.40368767, -1.16880835, -0.8399706 ],
#        [ 0.57094237, -0.77377003,  0.27222512],
#        [ 0.8517939 ,  0.64483716,  1.20593359]])

# %%
arr=np.array([1,3,5,3,3,5,3,3,4,6,8,8,9])
np.unique(arr)
# Out:
# array([1, 3, 4, 5, 6, 8, 9])
